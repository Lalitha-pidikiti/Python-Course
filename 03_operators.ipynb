# %%
a = 10
b = 20
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
print(a%b)
# Out:
# 30
# -10
# 200
# 0.5
# 0
# 10

# %%
a = 20
b = 15
a+= 100
b =b+100 
print(a)
print(b)
# Out:
# 120
# 115

# %%
a=10
b=20
print(a>b)
print(a<=b)
print(a>b)
# Out:
# False
# True
# False

# %%
a=12
b=15
print(a>b and a<b)
# Out:
# False

# %%
l1 = [10,20,30]
l2 = [10,20,30]
l3 = l1
print(id(l1),id(l2),id(l3))
# Out:
# 2565192659328 2565192657600 2565192659328

# %%
a = 10
b = 10
print(a is b)
print(a==b)
# Out:
# True
# True

# %%
a = int(input())
print(a)

# %%
a = int(input("enter a number"))
print(a)
# Out:
# enter a number 26576
# 26576

# %%
b = int(input())
print(b)
# Out:
#  29
# the enter value is

# %%
length = int(input())
breadth = int(input())
area = length*breadth
perimeter = 2*(length+breadth)
print("The area of rectangle" + str(area) "having length" + str(length) + "breadth" +str(breadth))
# Out:
#   Cell In[15], line 5
#     print("The area of rectangle" + str(area) "having length" + str(length) + "breadth" +str(breadth))
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
length = int(input())
breadth = int(input())
area = length*breadth
perimeter = 2*(length+breadth)
print("The area of rectangle" + str(area) "having length" + str(length) + "breadth" +str(breadth))
# Out:
#   Cell In[15], line 5
#     print("The area of rectangle" + str(area) "having length" + str(length) + "breadth" +str(breadth))
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
length = int(input())
breadth = int(input())
area = length*breadth
perimeter = 2*(length+breadth)
print("The area of rectangle" + str(area) "having length" + str(length) + "breadth" +str(breadth))
