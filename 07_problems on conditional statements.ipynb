# %%
n = int(input())
if n%2 ==0:
    print("Even")
else:
    print("odd")
# Out:
#  54
# Even

# %%
a,b = int(input())
if a>b:
    print("a is greater than b")
else:
    print("b is greater than a")
