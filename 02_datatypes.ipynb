# %%
s1 = {1, 2, 3}
s2 = {4, 2, 6, 7}
print(s1^s2)
print(s1.symmetric_difference(s2))
print(type(s1),type(s2))
# Out:
# {1, 3, 4, 6, 7}
# {1, 3, 4, 6, 7}
# <class 'set'> <class 'set'>

# %%
 set = {}
s4 = set()
s2 = {20,30,40}
s1 = {27,94,0}
print(type(s),type(s2),type(s1),type(s4))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 2
#       1 s = {}
# ----> 2 s4 = set()
#       3 s2 = {20,30,40}
#       4 s1 = {27,94,0}
#       5 print(type(s),type(s2),type(s1),type(s4))
#
# TypeError: 'dict' object is not callable
