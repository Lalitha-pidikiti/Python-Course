# %%
#Liat concatanation
l1 = [1,2,3,4,5]
l2 = [4,5]
print(l1+l2)
# Out:
# [1, 2, 3, 4, 5, 4, 5]

# %%
#repitition
print(7*8)
# Out:
# 56

# %%
lst = []
lst1 = list()
lst2 = [1,2,3,4,5]

# %%
t = (1,2,3)
l = list(t)
print(t)
# Out:
# (1, 2, 3)

# %%
print(
