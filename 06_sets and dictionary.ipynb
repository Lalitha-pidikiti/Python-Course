# %%
s1 = {1,2,3}
s2 = {1,3}
print(s1|s2)
# Out:
# {1, 2, 3}

# %%
s1 = {1,2,3}
s2 = {1,3,8,9}
print(s1.union(s2))
# Out:
# {1, 2, 3, 8, 9}

# %%
s1 = {1,2,3}
s2 = {1,3}
print(s1.intersection(s2))
# Out:
# {1, 3}

# %%
s1 = {1,2,3}
s2 = {1,3}
print(s1.difference(s2))
# Out:
# {2}

# %%
details = {'name':'lalitha','no':06,'CGPA':79.1}
print(details['no'])
